# %%
# Import Libraries
import tensorflow as tf

print(tf.__version__)
# Out:
# WARNING:tensorflow:From c:\Users\avani\Documents\DeepFER\ml_env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
# Define Dataset Paths
train_path = "../dataset/Archive-3/train"
test_path = "../dataset/Archive-3/test"

# %%
import os

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Check the Paths
print(os.listdir(train_path))
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# Count Images in Each Folder
for folder in os.listdir(train_path):
    folder_path = os.path.join(train_path, folder)
    print(folder, ":", len(os.listdir(folder_path)))
# Out:
# angry : 3995
# disgust : 436
# fear : 4097
# happy : 7215
# neutral : 4965
# sad : 4830
# surprise : 3171

# %%
# Load the Dataset
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(48, 48),
    batch_size=32,
    shuffle=True
)
# Out:
# Found 28709 files belonging to 7 classes.

# %%
# Check Class Names
class_names = train_dataset.class_names

print(class_names)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# Display Sample Images
plt.figure(figsize=(10,10))

for images, labels in train_dataset.take(1):

    for i in range(9):

        ax = plt.subplot(3,3,i+1)

        plt.imshow(images[i].numpy().astype("uint8"))

        plt.title(class_names[labels[i]])

        plt.axis("off")

# %%
# Check Image Shape
for images, labels in train_dataset.take(1):

    print(images.shape)

    print(labels.shape)
# Out:
# (32, 48, 48, 3)
# (32,)

# %%
# Load the Dataset
test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_path,
    image_size=(48,48),
    batch_size=32,
    shuffle=False
)
# Out:
# Found 7178 files belonging to 7 classes.

# %%
print(class_names)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
